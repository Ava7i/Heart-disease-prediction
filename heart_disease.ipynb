# %% [markdown]
# # <h1 style="font-family: Trebuchet MS; padding: 12px; font-size: 48px; color: #BA1141; text-align: center; line-height: 1.25;"><b> Heart Disease<span style="color: #000000"> EDA & Prediction 🔮</span></b><br><span style="color: #FF5C8A; font-size: 24px">with Various Machine Learning Models </span></h1>
# <hr>
# ​

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # <div style="font-family: Trebuchet MS; background-color: #8A0030; color: #FFFFFF; padding: 12px; line-height: 1.5;">1. | Introduction 👋</div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os
import yellowbrick
import pickle

from matplotlib.collections import PathCollection
from statsmodels.graphics.gofplots import qqplot
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, ExtraTreesClassifier
from sklearn.metrics import classification_report, accuracy_score
from xgboost import XGBClassifier
from yellowbrick.classifier import PrecisionRecallCurve, ROCAUC, ConfusionMatrix
from yellowbrick.style import set_palette
from yellowbrick.model_selection import LearningCurve, FeatureImportances
from yellowbrick.contrib.wrapper import wrap

# --- Libraries Settings ---
warnings.filterwarnings('ignore')
sns.set_style('whitegrid')
plt.rcParams['figure.dpi']=100
set_palette('dark')

# %% [markdown]
# # <div style="font-family: Trebuchet MS; background-color: #8A0030; color: #FFFFFF; padding: 12px; line-height: 1.5;">3. | Color Palettes 🎨</div>
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#     👉 This section will create some <b>color palettes</b> that will be used in this notebook.
# </div>

# %%
# --- Create List of Color Palletes ---
red_grad = ['#FF0000', '#BF0000', '#800000', '#400000', '#000000']
pink_grad = ['#8A0030', '#BA1141', '#FF5C8A', '#FF99B9', '#FFDEEB']
purple_grad = ['#4C0028', '#7F0043', '#8E004C', '#A80059', '#C10067']
color_mix = ['#F38BB2', '#FFB9CF', '#FFD7D7', '#F17881', '#E7525B']
black_grad = ['#100C07', '#3E3B39', '#6D6A6A', '#9B9A9C', '#CAC9CD']

# --- Plot Color Palletes --
sns.palplot(red_grad)
sns.palplot(pink_grad)
sns.palplot(purple_grad)
sns.palplot(color_mix)
sns.palplot(black_grad)

# %% [markdown]
# # <div style="font-family: Trebuchet MS; background-color: #8A0030; color: #FFFFFF; padding: 12px; line-height: 1.5;">2. | Importing Libraries 📚</div>
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#     👉 <b>Importing libraries</b> that will be used in this notebook.
# </div>
# <!-- Hello world 👋. Thank you so much for downloading/forking my codes/works. If you like my works, please support me by giving upvotes and comments on my Kaggle profile (https://www.kaggle.com/caesarmario/). Thank you so much and have a great day 😆👍. More about me: https://linktr.ee/caesarmario_ -->

# %% [markdown]
# # <div style="font-family: Trebuchet MS; background-color: #8A0030; color: #FFFFFF; padding: 12px; line-height: 1.5;">4. | Reading Dataset 👓</div>
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#     👉 After importing libraries, <b>the dataset that will be used will be imported</b>.
# </div>

# %%
# --- Importing Dataset ---
dataset1 = pd.read_csv('/content/drive/MyDrive/heart/heart data/heart.csv')

# --- Reading Dataset ---
dataset1.head().style.background_gradient(cmap='icefire').set_properties(**{'font-family': 'Segoe UI'}).hide_index()
# Out:
# <style type="text/css">
# #T_61178_row0_col0, #T_61178_row0_col2, #T_61178_row0_col3, #T_61178_row0_col5, #T_61178_row0_col8, #T_61178_row0_col13, #T_61178_row1_col2, #T_61178_row1_col6, #T_61178_row1_col10, #T_61178_row1_col11, #T_61178_row1_col13, #T_61178_row2_col2, #T_61178_row2_col4, #T_61178_row2_col5, #T_61178_row2_col10, #T_61178_row2_col11, #T_61178_row2_col13, #T_61178_row3_col2, #T_61178_row3_col5, #T_61178_row3_col8, #T_61178_row3_col9, #T_61178_row3_col13, #T_61178_row4_col1, #T_61178_row4_col2, #T_61178_row4_col7, #T_61178_row4_col8, #T_61178_row4_col12, #T_61178_row4_col13 {
#   background-color: #bde7db;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T

#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_97946_row0_col5 {
#   background-color: #e7f6ad;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_97946_row0_col10 {
#   background-color: #51b365;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_97946_row1_col0 {
#   background-color: #d9f0a3;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_97946_row1_col3 {
#   background-color: #379e54;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_97946_row1_col4, #T_97946_row2_col4 {
#   background-color: #a2d88a;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_97946_row1_col5 {
#   background-color: #c5e89a;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_97946_row2_col0 {
#   background-color: #77c679;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_97946_row2_col1 {
#   background-color: #f0f9b4;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_97946_row2_col3, #T_97946_row3_col3 {
#   background-color: #bce395;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_97946_row2_col8 {
#   background-color: #4eb163;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_97946_row2_col10 {
#   background-color: #d0ec9f;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_97946_row3_col0 {
#   background-color: #228343;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_97946_row3_col1 {
#   background-color: #278946;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_97946_row3_col5 {
#   background-color: #e2f4aa;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_97946_row3_col8 {
#   background-color: #218242;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_97946_row3_col10 {
#   background-color: #fbfdce;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_97946_row4_col1 {
#   background-color: #1e8041;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_97946_row4_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_97946_row4_col8 {
#   background-color: #b6e192;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_97946_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Unnamed: 0</th>
#       <th class="col_heading level0 col1" >age</th>
#       <th class="col_heading level0 col2" >sex</th>
#       <th class="col_heading level0 col3" >cp</th>
#       <th class="col_heading level0 col4" >trestbps</th>
#       <th class="col_heading level0 col5" >chol</th>
#       <th class="col_heading level0 col6" >fbs</th>
#       <th class="col_heading level0 col7" >restecg</th>
#       <th class="col_heading level0 col8" >thalach</th>
#       <th class="col_heading level0 col9" >exang</th>
#       <th class="col_heading level0 col10" >oldpeak</th>
#       <th class="col_heading level0 col11" >slope</th>
#       <th class="col_heading level0 col12" >ca</th>
#       <th class="col_heading level0 col13" >thal</th>
#       <th class="col_heading level0 col14" >target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_97946_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_97946_row0_col1" class="data row0 col1" >63</td>
#       <td id="T_97946_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_97946_row0_col3" class="data row0 col3" >3</td>
#       <td id="T_97946_row0_col4" class="data row0 col4" >145.000000</td>
#       <td id="T_97946_row0_col5" class="data row0 col5" >233.000000</td>
#       <td id="T_97946_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_97946_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_97946_row0_col8" class="data row0 col8" >150.000000</td>
#       <td id="T_97946_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_97946_row0_col10" class="data row0 col10" >2.300000</td>
#       <td id="T_97946_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_97946_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_97946_row0_col13" class="data row0 col13" >1</td>
#       <td id="T_97946_row0_col14" class="data row0 col14" >1</td>
#     </tr>
#     <tr>
#       <td id="T_97946_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_97946_row1_col1" class="data row1 col1" >37</td>
#       <td id="T_97946_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_97946_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_97946_row1_col4" class="data row1 col4" >130.000000</td>
#       <td id="T_97946_row1_col5" class="data row1 col5" >250.000000</td>
#       <td id="T_97946_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_97946_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_97946_row1_col8" class="data row1 col8" >187.000000</td>
#       <td id="T_97946_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_97946_row1_col10" class="data row1 col10" >3.500000</td>
#       <td id="T_97946_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_97946_row1_col12" class="data row1 col12" >0</td>
#       <td id="T_97946_row1_col13" class="data row1 col13" >2</td>
#       <td id="T_97946_row1_col14" class="data row1 col14" >1</td>
#     </tr>
#     <tr>
#       <td id="T_97946_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_97946_row2_col1" class="data row2 col1" >41</td>
#       <td id="T_97946_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_97946_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_97946_row2_col4" class="data row2 col4" >130.000000</td>
#       <td id="T_97946_row2_col5" class="data row2 col5" >204.000000</td>
#       <td id="T_97946_row2_col6" class="data row2 col6" >0</td>
#       <td id="T
row4_col2" class="data row4 col2" >0</td>
#       <td id="T_47912_row4_col3" class="data row4 col3" >120</td>
#       <td id="T_47912_row4_col4" class="data row4 col4" >354</td>
#       <td id="T_47912_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_47912_row4_col6" class="data row4 col6" >1</td>
#       <td id="T_47912_row4_col7" class="data row4 col7" >163</td>
#       <td id="T_47912_row4_col8" class="data row4 col8" >1</td>
#       <td id="T_47912_row4_col9" class="data row4 col9" >0.600000</td>
#       <td id="T

# %%
# --- Importing Dataset ---
dataset4 = pd.read_csv('//content/drive/MyDrive/heart/heart data/data.csv')

# --- Reading Dataset ---
dataset4.head().style.background_gradient(cmap='icefire_r').set_properties(**{'font-family': 'Segoe UI'}).hide_index()
# Out:
# <style type="text/css">
# #T_74d9e_row0_col0 {
#   background-color: #3b71cd;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_74d9e_row0_col1, #T_74d9e_row0_col2, #T_74d9e_row0_col3, #T_74d9e_row0_col6, #T_74d9e_row0_col9, #T_74d9e_row0_col10, #T_74d9e_row0_col11, #T_74d9e_row0_col13, #T_74d9e_row1_col4, #T_74d9e_row1_col6, #T_74d9e_row1_col7, #T_74d9e_row1_col10, #T_74d9e_row1_col12, #T_74d9e_row2_col1, #T_74d9e_row2_col12, #T_74d9e_row2_col13, #T_74d9e_row3_col1, #T_74d9e_row3_col2, #T_74d9e_row3_col8, #T_74d9e_row3_col10, #T_74d9e_row3_col12, #T_74d9e_row4_col0, #T_74d9e_row4_col6, #T_74d9e_row4_col8 {
#   background-color: #bde7db;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_74d9e_row0_col4 {
#   background-color: #d34936;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_74d9e_row0_col5, #T_74d9e_row0_col8, #T_74d9e_row0_col12, #T_74d9e_row1_col1, #T_74d9e_row1_col3, #T_74d9e_row1_col5, #T_74d9e_row1_col8, #T_74d9e_row1_col11, #T_74d9e_row1_col13, #T_74d9e_row2_col0, #T_74d9e_row2_col2, #T_74d9e_row2_col4, #T_74d9e_row2_col5, #T_74d9e_row2_col6, #T_74d9e_row2_col8, #T_74d9e_row2_col10, #T_74d9e_row2_col11, #T_74d9e_row3_col5, #T_74d9e_row3_col6, #T_74d9e_row3_col7, #T_74d9e_row3_col9, #T_74d9e_row3_col13, #T_74d9e_row4_col1, #T_74d9e_row4_col2, #T_74d9e_row4_col5, #T_74d9e_row4_col9, #T_74d9e_row4_col10, #T_74d9e_row4_col12, #T_74d9e_row4_col13 {
#   background-color: #ffd4ac;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_74d9e_row0_col7 {
#   background-color: #f5a36a;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_74d9e_row1_col0 {
#   background-color: #2c2b42;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_74d9e_row1_col2 {
#   background-color: #1f1e1e;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_74d9e_row1_col9 {
#   background-color: #3b3866;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_74d9e_row2_col3 {
#   background-color: #302e4a;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_74d9e_row2_col7 {
#   background-color: #413e77;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_74d9e_row2_col9 {
#   background-color: #f9b684;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_74d9e_row3_col0 {
#   background-color: #43232a;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_74d9e_row3_col3 {
#   background-color: #5aa7cd;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_74d9e_row3_col4 {
#   background-color: #fed1a9;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_74d9e_row3_col11, #T_74d9e_row4_col3, #T_74d9e_row4_col11 {
#   background-color: #782c3f;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_74d9e_row4_col4 {
#   background-color: #fcc396;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_74d9e_row4_col7 {
#   background-color: #992e44;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_74d9e_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >age</th>
#       <th class="col_heading level0 col1" >sex</th>
#       <th class="col_heading level0 col2" >cp</th>
#       <th class="col_heading level0 col3" >trestbps</th>
#       <th class="col_heading level0 col4" >chol</th>
#       <th class="col_heading level0 col5" >fbs</th>
#       <th class="col_heading level0 col6" >restecg</th>
#       <th class="col_heading level0 col7" >thalach</th>
#       <th class="col_heading level0 col8" >exang</th>
#       <th class="col_heading level0 col9" >oldpeak</th>
#       <th class="col_heading level0 col10" >slope</th>
#       <th class="col_heading level0 col11" >ca</th>
#       <th class="col_heading level0 col12" >thal</th>
#       <th class="col_heading level0 col13" >target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_74d9e_row0_col0" class="data row0 col0" >70</td>
#       <td id="T_74d9e_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_74d9e_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_74d9e_row0_col3" class="data row0 col3" >130</td>
#       <td id="T_74d9e_row0_col4" class="data row0 col4" >322</td>
#       <td id="T_74d9e_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_74d9e_row0_col6" class="data row0 col6" >2</td>
#       <td id="T_74d9e_row0_col7" class="data row0 col7" >109</td>
#       <td id="T_74d9e_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_74d9e_row0_col9" class="data row0 col9" >2.400000</td>
#       <td id="T_74d9e_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_74d9e_row0_col11" class="data row0 col11" >3</td>
#       <td id="T_74d9e_row0_col12" class="data row0 col12" >3</td>
#       <td id="T_74d9e_row0_col13" class="data row0 col13" >2</td>
#     </tr>
#     <tr>
#       <td id="T_74d9e_row1_col0" class="data row1 col0" >67</td>
#       <td id="T_74d9e_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_74d9e_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_74d9e_row1_col3" class="data row1 col3" >115</td>
#       <td id="T_74d9e_row1_col4" class="data row1 col4" >564</td>
#       <td id="T_74d9e_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_74d9e_row1_col6" class="data row1 col6" >2</td>
#       <td id="T_74d9e_row1_col7" class="data row1 col7" >160</td>
#       <td id="T_74d9e_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_74d9e_row1_col9" class="data row1 col9" >1.600000</td>
#       <td id="T_74d9e_row1_col10" class="data row1 col10" >2</td>
#       <td id="T_74d9e_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_74d9e_row1_col12" class="data row1 col12" >7</td>
#       <td id="T_74d9e_row1_col13" class="data row1 col13" >1</td>
#     </tr>
#     <tr>
#       <td id="T_74d9e_row2_col0" class="data row2 col0" >57</td>
#       <td id="T_74d9e_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_74d9e_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_74d9e_row2_col3" class="data row2 col3" >124</td>
#       <td id="T_74d9e_row2_col4" class="data row2 col4" >261</td>
#       <td id="T_74d9e_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_74d9e_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_74d9e_row2_col7" class="data row2 col7" >141</td>
#       <td id="T_74d9e_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_74d9e_row2_col9" class="data row2 col9" >0.300000</td>
#       <td id="T_74d9e_row2_col10" class="data row2 col10" >1</td>
#       <td id="T_74d9e_row2_col11" class="data row2 col11" >0</td>
#       <td id="T_74d9e_row2_col12" class="data row2 col12" >7</td>
#       <td id="T_74d9e_row2_col13" class="data row2 col13" >2</td>
#     </tr>
#     <tr>
#       <td id="T_74d9e_row3_col0" class="data row3 col0" >64</td>
#       <td id="T_74d9e_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_74d9e_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_74d9e_row3_col3" class="data row3 col3" >128</td>
#       <td id="T_74d9e_row3_col4" class="data row3 col4" >263</td>
#       <td id="T_74d9e_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_74d9e_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_74d9e_row3_col7" class="data row3 col7" >105</td>
#       <td id="T_74d9e_row3_col8" class="data row3 col8" >1</td>
#       <td id="T_74d9e_row3_col9" class="data row3 col9" >0.200000</td>
#       <td id="T_74d9e_row3_col10" class="data row3 col10" >2</td>
#       <td id="T_74d9e_row3_col11" class="data row3 col11" >1</td>
#       <td id="T_74d9e_row3_col12" class="data row3 col12" >7</td>
#       <td id="T_74d9e_row3_col13" class="data row3 col13" >1</td>
#     </tr>
#     <tr>
#       <td id="T_74d9e_row4_col0" class="data row4 col0" >74</td>
#       <td id="T_74d9e_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_74d9e_row4_col2" class="data row4 col2" >2</td>
#       <td id="T_74d9e_row4_col3" class="data row4 col3" >120</td>
#       <td id="T_74d9e_row4_col4" class="data row4 col4" >269</td>
#       <td id="T_74d9e_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_74d9e_row4_col6" class="data row4 col6" >2</td>
#       <td id="T_74d9e_row4_col7" class="data row4 col7" >121</td>
#       <td id="T_74d9e_row4_col8" class="data row4 col8" >1</td>
#       <td id="T_74d9e_row4_col9" class="data row4 col9" >0.200000</td>
#       <td id="T

# %%
dataset1.shape
# Out:
# (1025, 14)

# %%
dataset2.shape
# Out:
# (303, 14)

# %%
dataset3.shape
# Out:
# (303, 14)

# %%
dataset4.shape
# Out:
# (270, 14)

# %%
dataset2.columns
# Out:
# Index(['Unnamed: 0', 'age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg',
#        'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# After droping unnamed: 0 column

# %%
display(dataset1.shape,dataset2.shape)
# Out:
# (1025, 14)
# (303, 14)

# %%
df = pd.concat([dataset1, dataset2,dataset3,dataset4])
df.shape
# Out:
# (1901, 14)

# %%
# --- Reading Dataset ---
dataset4.head().style.background_gradient(cmap='binary').set_properties(**{'font-family': 'Segoe UI'}).hide_index()
# Out:
# <style type="text/css">
# #T_205b4_row0_col0 {
#   background-color: #3c3c3c;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_205b4_row0_col1, #T_205b4_row0_col2, #T_205b4_row0_col3, #T_205b4_row0_col6, #T_205b4_row0_col9, #T_205b4_row0_col10, #T_205b4_row0_col11, #T_205b4_row0_col13, #T_205b4_row1_col4, #T_205b4_row1_col6, #T_205b4_row1_col7, #T_205b4_row1_col10, #T_205b4_row1_col12, #T_205b4_row2_col1, #T_205b4_row2_col12, #T_205b4_row2_col13, #T_205b4_row3_col1, #T_205b4_row3_col2, #T_205b4_row3_col8, #T_205b4_row3_col10, #T_205b4_row3_col12, #T_205b4_row4_col0, #T_205b4_row4_col6, #T_205b4_row4_col8 {
#   background-color: #000000;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_205b4_row0_col4 {
#   background-color: #cccccc;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_205b4_row0_col5, #T_205b4_row0_col8, #T_205b4_row0_col12, #T_205b4_row1_col1, #T_205b4_row1_col3, #T_205b4_row1_col5, #T_205b4_row1_col8, #T_205b4_row1_col11, #T_205b4_row1_col13, #T_205b4_row2_col0, #T_205b4_row2_col2, #T_205b4_row2_col4, #T_205b4_row2_col5, #T_205b4_row2_col6, #T_205b4_row2_col8, #T_205b4_row2_col10, #T_205b4_row2_col11, #T_205b4_row3_col5, #T_205b4_row3_col6, #T_205b4_row3_col7, #T_205b4_row3_col9, #T_205b4_row3_col13, #T_205b4_row4_col1, #T_205b4_row4_col2, #T_205b4_row4_col5, #T_205b4_row4_col9, #T_205b4_row4_col10, #T_205b4_row4_col12, #T_205b4_row4_col13 {
#   background-color: #ffffff;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_205b4_row0_col7 {
#   background-color: #ededed;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_205b4_row1_col0 {
#   background-color: #696969;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_205b4_row1_col2 {
#   background-color: #7f7f7f;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_205b4_row1_col9 {
#   background-color: #5d5d5d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_205b4_row2_col3 {
#   background-color: #666666;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_205b4_row2_col7 {
#   background-color: #585858;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_205b4_row2_col9 {
#   background-color: #f4f4f4;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_205b4_row3_col0 {
#   background-color: #969696;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_205b4_row3_col3 {
#   background-color: #222222;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_205b4_row3_col4 {
#   background-color: #fefefe;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_205b4_row3_col11, #T_205b4_row4_col3, #T_205b4_row4_col11 {
#   background-color: #aaaaaa;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T
row4_col1" class="data row4 col1" >0</td>
#       <td id="T_205b4_row4_col2" class="data row4 col2" >2</td>
#       <td id="T_205b4_row4_col3" class="data row4 col3" >120</td>
#       <td id="T_205b4_row4_col4" class="data row4 col4" >269</td>
#       <td id="T_205b4_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_205b4_row4_col6" class="data row4 col6" >2</td>
#       <td id="T_205b4_row4_col7" class="data row4 col7" >121</td>
#       <td id="T_205b4_row4_col8" class="data row4 col8" >1</td>
#       <td id="T_205b4_row4_col9" class="data row4 col9" >0.200000</td>
#       <td id="T

# %%
# --- Print Dataset Info ---
print('\033[1m'+'.: Dataset Info :.'+'\033[0m')
print('*' * 30)
print('Total Rows:'+'\033[1m', df.shape[0])
print('\033[0m'+'Total Columns:'+'\033[1m', df.shape[1])
print('\033[0m'+'*' * 30)
print('\n')

# --- Print Dataset Detail ---
print('\033[1m'+'.: Dataset Details :.'+'\033[0m')
print('*' * 30)
df.info(memory_usage = False)
# Out:
# .: Dataset Info :.
# ******************************
# Total Rows: 1901
# Total Columns: 14
# ******************************
#
#
# .: Dataset Details :.
# ******************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1901 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1901 non-null   int64
#  1   sex       1901 non-null   int64
#  2   cp        1901 non-null   int64
#  3   trestbps  1901 non-null   int64
#  4   chol      1901 non-null   int64
#  5   fbs       1901 non-null   int64
#  6   restecg   1901 non-null   int64
#  7   thalach   1901 non-null   int64
#  8   exang     1901 non-null   int64
#  9   oldpeak   1901 non-null   float64
#  10  slope     1901 non-null   int64
#  11  ca        1901 non-null   int64
#  12  thal      1901 non-null   int64
#  13  target    1901 non-null   int64
# dtypes: float64(1), int64(13)

# %% [markdown]
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#     👉 It can be seen that dataset has successfully imported.<br>
#     👉 In the dataset, there are <mark><b>14 columns</b></mark> with <mark><b>303 observations</b></mark>. Also, there are <mark><b>no null values</b></mark> in this dataset. The <b>details of each variables</b> also can be seen above.<br>
#     👉 However, the <mark><b>data types for some columns are not matched</b></mark>. Below will <mark><b>fixed the data types for those column</b></mark> before analysis performed.

# %%
# --- Fix Data Types ---
lst=['oldpeak']
df[lst] = df[lst].astype(int)

# %% [markdown]
# # <div style="font-family: Trebuchet MS; background-color: #8A0030; color: #FFFFFF; padding: 12px; line-height: 1.5;">  Initial Data Exploration 🔍</div>
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#     👉 This section will focused on <b>initial data exploration</b> before applying ML models.

# %% [markdown]
# ### <div style="font-family: Trebuchet MS; background-color: #FF5C8A; color: #FFFFFF; padding: 12px; line-height: 1.5;">  sex (Gender)</div>

# %%
# --- Setting Colors, Labels, Order ---
colors=color_mix[2:4]
labels=['Female', 'Male']
order=df['sex'].value_counts().index

# --- Size for Both Figures ---
plt.figure(figsize=(16, 8))
plt.suptitle('Sex (Gender) Distribution', fontweight='heavy', 
             fontsize='16', fontfamily='sans-serif', color=black_grad[0])

# --- Pie Chart ---
plt.subplot(1, 2, 1)
plt.title('Pie Chart', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
plt.pie(df['sex'].value_counts(), labels=labels, colors=colors, pctdistance=0.7,
        autopct='%.2f%%', wedgeprops=dict(alpha=0.8, edgecolor=black_grad[1]),
        textprops={'fontsize':12})
centre=plt.Circle((0, 0), 0.45, fc='white', edgecolor=black_grad[1])
plt.gcf().gca().add_artist(centre)

# --- Histogram ---
countplt = plt.subplot(1, 2, 2)
plt.title('Histogram', fontweight='bold', fontsize=14, 
          fontfamily='sans-serif', color=black_grad[0])
ax = sns.countplot(x='sex', data=df, palette=colors, order=order,
                   edgecolor=black_grad[2], alpha=0.85)
for rect in ax.patches:
    ax.text (rect.get_x()+rect.get_width()/2, 
             rect.get_height()+4.25,rect.get_height(), 
             horizontalalignment='center', fontsize=10, 
             bbox=dict(facecolor='none', edgecolor=black_grad[0], 
                       linewidth=0.25, boxstyle='round'))

plt.xlabel('Gender', fontweight='bold', fontsize=11, fontfamily='sans-serif', 
           color=black_grad[1])
plt.ylabel('Total', fontweight='bold', fontsize=11, fontfamily='sans-serif', 
           color=black_grad[1])
plt.xticks([0, 1], labels)
plt.grid(axis='y', alpha=0.4)
countplt
# --- Count Categorical Labels w/out Dropping Null Walues ---
print('*' * 25)
print('\033[1m'+'.: Sex (Gender) Total :.'+'\033[0m')
print('*' * 25)
df.sex.value_counts(dropna=False)
# Out:
# *************************
# .: Sex (Gender) Total :.
# *************************
# 1    1310
# 0     591
# Name: sex, dtype: int64

# %% [markdown]
# ### <div style="font-family: Trebuchet MS; background-color: #FF5C8A; color: #FFFFFF; padding: 12px; line-height: 1.5;">  cp (Chest Pain Type)</div>

# %%
# --- Setting Colors, Labels, Order ---
colors=pink_grad[0:4]
labels=['Type 0', 'Type 2', 'Type 1', 'Type 3']
order=df['cp'].value_counts().index

# --- Size for Both Figures ---
plt.figure(figsize=(16, 8))
plt.suptitle('Chest Pain Type Distribution', fontweight='heavy', fontsize=16, 
             fontfamily='sans-serif', color=black_grad[0])



# --- Histogram ---
countplt = plt.subplot(1, 2, 2)
plt.title('Histogram', fontweight='bold', fontsize=14, fontfamily='sans-serif', 
          color=black_grad[0])
ax = sns.countplot(x='cp', data=df, palette=colors, order=order,
                   edgecolor=black_grad[2], alpha=0.85)
for rect in ax.patches:
    ax.text (rect.get_x()+rect.get_width()/2, 
             rect.get_height()+4.25,rect.get_height(), 
             horizontalalignment='center', fontsize=10,
             bbox=dict(facecolor='none', edgecolor=black_grad[0], linewidth=0.25,
                       boxstyle='round'))

plt.xlabel('Pain Type', fontweight='bold', fontsize=11, fontfamily='sans-serif', 
           color=black_grad[1])
plt.ylabel('Total', fontweight='bold', fontsize=11, fontfamily='sans-serif', 
           color=black_grad[1])
plt.xticks([0, 1, 2, 3], labels)
plt.grid(axis='y', alpha=0.4)
countplt

# --- Count Categorical Labels w/out Dropping Null Walues ---
print('*' * 30)
print('\033[1m'+'.: Chest Pain Type Total :.'+'\033[0m')
print('*' * 30)
df.cp.value_counts(dropna=False)
# Out:
# ******************************
# .: Chest Pain Type Total :.
# ******************************
# 0    783
# 2    500
# 1    287
# 3    202
# 4    129
# Name: cp, dtype: int64

# %% [markdown]
# ### <div style="font-family: Trebuchet MS; background-color: #FF5C8A; color: #FFFFFF; padding: 12px; line-height: 1.5;"> fbs (Fasting Blood Sugar)</div>

# %%
# --- Setting Colors, Labels, Order ---
colors=color_mix[0:2]
labels=['< 120 mg/dl', '> 120 mg/dl']
order=df['fbs'].value_counts().index

# --- Size for Both Figures ---
plt.figure(figsize=(16, 8))
plt.suptitle('Fasting Blood Sugar Distribution', fontweight='heavy', 
             fontsize=16, fontfamily='sans-serif', color=black_grad[0])

# --- Pie Chart ---
plt.subplot(1, 2, 1)
plt.title('Pie Chart', fontweight='bold', fontsize=14, fontfamily='sans-serif', 
          color=black_grad[0])
plt.pie(df['fbs'].value_counts(), labels=labels, colors=colors,
        wedgeprops=dict(alpha=0.8, edgecolor=black_grad[1]), autopct='%.2f%%',
        pctdistance=0.7, textprops={'fontsize':12})
centre=plt.Circle((0, 0), 0.45, fc='white', edgecolor=black_grad[1])
plt.gcf().gca().add_artist(centre)

# --- Histogram ---
countplt = plt.subplot(1, 2, 2)
plt.title('Histogram', fontweight='bold', fontsize=14, fontfamily='sans-serif', 
          color=black_grad[0])
ax = sns.countplot(x='fbs', data=df, palette=colors, order=order,
                   edgecolor=black_grad[2], alpha=0.85)
for rect in ax.patches:
    ax.text (rect.get_x()+rect.get_width()/2, 
             rect.get_height()+4.25,rect.get_height(), 
             horizontalalignment='center', fontsize=10,
             bbox=dict(facecolor='none', edgecolor=black_grad[0], linewidth=0.25,
                       boxstyle='round'))

plt.xlabel('Fasting Blood Sugar', fontweight='bold', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])
plt.ylabel('Total', fontweight='bold', fontsize=11, fontfamily='sans-serif', 
           color=black_grad[1])
plt.xticks([0, 1], labels)
plt.grid(axis='y', alpha=0.4)
countplt


# --- Count Categorical Labels w/out Dropping Null Walues ---
print('*' * 32)
print('\033[1m'+'.: Fasting Blood Sugar Total :.'+'\033[0m')
print('*' * 32)
df.fbs.value_counts(dropna=False)
# Out:
# ********************************
# .: Fasting Blood Sugar Total :.
# ********************************
# 0    1618
# 1     283
# Name: fbs, dtype: int64

# %% [markdown]
# ### <div style="font-family: Trebuchet MS; background-color: #FF5C8A; color: #FFFFFF; padding: 12px; line-height: 1.5;">  restecg (Resting Electrocardiographic Results)</div>

# %%
# --- Setting Colors, Labels, Order ---
colors=pink_grad[1:4]
labels=['1', '0', '2']
order=df['restecg'].value_counts().index

# --- Size for Both Figures ---
plt.figure(figsize=(16, 8))
plt.suptitle('Resting Electrocardiographic Distribution', fontweight='heavy', 
             fontsize=16, fontfamily='sans-serif', color=black_grad[0])

# --- Pie Chart ---
plt.subplot(1,2,1)
plt.title('Pie Chart', fontweight='bold', fontsize=14, fontfamily='sans-serif', 
          color=black_grad[0])
plt.pie(df['restecg'].value_counts(), labels=labels, colors=colors, 
        wedgeprops=dict(alpha=0.8, edgecolor=black_grad[1]), autopct='%.2f%%',
        pctdistance=0.7, textprops={'fontsize':12})
centre=plt.Circle((0, 0), 0.45, fc='white', edgecolor=black_grad[1])
plt.gcf().gca().add_artist(centre)

# --- Histogram ---
countplt = plt.subplot(1, 2, 2)
plt.title('Histogram', fontweight='bold', fontsize=14, fontfamily='sans-serif', 
          color=black_grad[0])
ax = sns.countplot(x='restecg', data=df, palette=colors, order=order,
                   edgecolor=black_grad[2], alpha=0.85)
for rect in ax.patches:
    ax.text (rect.get_x()+rect.get_width()/2, 
             rect.get_height()+4.25,rect.get_height(), 
             horizontalalignment='center', fontsize=10,
             bbox=dict(facecolor='none', edgecolor=black_grad[0], linewidth=0.25,
                       boxstyle='round'))

plt.xlabel('Resting Electrocardiographic', fontweight='bold', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])
plt.ylabel('Total', fontweight='bold', fontsize=11, fontfamily='sans-serif', 
           color=black_grad[1])
plt.grid(axis='y', alpha=0.4)
countplt

# --- Count Categorical Labels w/out Dropping Null Walues ---
print('*' * 50)
print('\033[1m'+'.: Resting Electrocardiographic Results Total :.'+'\033[0m')
print('*' * 50)
df.restecg.value_counts(dropna=False)
# Out:
# **************************************************
# .: Resting Electrocardiographic Results Total :.
# **************************************************
# 0    922
# 1    819
# 2    160
# Name: restecg, dtype: int64

# %% [markdown]
# ### <div style="font-family: Trebuchet MS; background-color: #FF5C8A; color: #FFFFFF; padding: 12px; line-height: 1.5;">  exang (Exercise Induced Angina)</div>

# %%
# --- Setting Colors, Labels, Order ---
colors=red_grad[1:3]
labels=['False', 'True']
order=df['exang'].value_counts().index

# --- Size for Both Figures ---
plt.figure(figsize=(16, 8))
plt.suptitle('Exercise Induced Angina Distribution', fontweight='heavy', 
             fontsize=16, fontfamily='sans-serif', color=black_grad[0])

# --- Pie Chart ---
plt.subplot(1,2,1)
plt.title('Pie Chart', fontweight='bold', fontsize=14, fontfamily='sans-serif',
          color=black_grad[0])
plt.pie(df['exang'].value_counts(), labels=labels, colors=colors, 
        wedgeprops=dict(alpha=0.8, edgecolor=black_grad[1]), autopct='%.2f%%',
        pctdistance=0.7, textprops={'fontsize':12})
centre=plt.Circle((0, 0), 0.45, fc='white', edgecolor=black_grad[1])
plt.gcf().gca().add_artist(centre)

# --- Histogram ---
countplt = plt.subplot(1, 2, 2)
plt.title('Histogram', fontweight='bold', fontsize=14, fontfamily='sans-serif', 
          color=black_grad[0])
ax = sns.countplot(x='exang', data=df, palette=colors, order=order,
                   edgecolor=black_grad[2], alpha=0.85)
for rect in ax.patches:
    ax.text (rect.get_x()+rect.get_width()/2, 
             rect.get_height()+4.25,rect.get_height(), 
             horizontalalignment='center', fontsize=10,
             bbox=dict(facecolor='none', edgecolor=black_grad[0], linewidth=0.25,
                       boxstyle='round'))

plt.xlabel('Exercise Induced Angina', fontweight='bold', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])
plt.ylabel('Total', fontweight='bold', fontsize=11, fontfamily='sans-serif', 
           color=black_grad[1])
plt.xticks([0, 1], labels)
plt.grid(axis='y', alpha=0.4)
countplt

# --- Count Categorical Labels w/out Dropping Null Walues ---
print('*' * 35)
print('\033[1m'+'.: Exercise Induced Angina Total :.'+'\033[0m')
print('*' * 35)
df.exang.value_counts(dropna=False)
# Out:
# ***********************************
# .: Exercise Induced Angina Total :.
# ***********************************
# 0    1269
# 1     632
# Name: exang, dtype: int64

# %% [markdown]
# ### <div style="font-family: Trebuchet MS; background-color: #FF5C8A; color: #FFFFFF; padding: 12px; line-height: 1.5;">  slope (Slope of the Peak Exercise)</div>

# %%
# --- Setting Colors, Labels, Order ---
colors=purple_grad[2:5]
labels=['2', '1', '0']
order=df['slope'].value_counts().index

# --- Size for Both Figures ---
plt.figure(figsize=(16, 8))
plt.suptitle('Slope of the Peak Exercise Distribution', fontweight='heavy', 
             fontsize=16, fontfamily='sans-serif', color=black_grad[0])



# --- Histogram ---
countplt = plt.subplot(1, 2, 2)
plt.title('Histogram', fontweight='bold', fontsize=14, fontfamily='sans-serif', 
          color=black_grad[0])
ax = sns.countplot(x='slope', data=df, palette=colors, order=order,
                   edgecolor=black_grad[2], alpha=0.85)
for rect in ax.patches:
    ax.text (rect.get_x()+rect.get_width()/2, 
             rect.get_height()+4.25,rect.get_height(), 
             horizontalalignment='center', fontsize=10,
             bbox=dict(facecolor='none', edgecolor=black_grad[0], linewidth=0.25,
                       boxstyle='round'))

plt.xlabel('Slope', fontweight='bold', fontsize=11, fontfamily='sans-serif', 
           color=black_grad[1])
plt.ylabel('Total', fontweight='bold', fontsize=11, fontfamily='sans-serif', 
           color=black_grad[1])
plt.grid(axis='y', alpha=0.4)
countplt
# --- Count Categorical Labels w/out Dropping Null Walues ---
print('*' * 20)
print('\033[1m'+'.: Slope Total :.'+'\033[0m')
print('*' * 20)
df.slope.value_counts(dropna=False)
# Out:
# ********************
# .: Slope Total :.
# ********************
# 1    892
# 2    875
# 0    116
# 3     18
# Name: slope, dtype: int64

# %% [markdown]
# ### <div style="font-family: Trebuchet MS; background-color: #FF5C8A; color: #FFFFFF; padding: 12px; line-height: 1.5;">  ca (Number of Major Vessels)</div>

# %%
# --- Setting Colors, Labels, Order ---
colors=purple_grad
labels=['0', '1', '2', '3', '4']
order=df['ca'].value_counts().index

# --- Size for Both Figures ---
plt.figure(figsize=(16, 8))
plt.suptitle('Number of Major Vessels Distribution', fontweight='heavy', 
             fontsize=16, fontfamily='sans-serif', color=black_grad[0])

# --- Pie Chart ---
plt.subplot(1,2,1)
plt.title('Pie Chart', fontweight='bold', fontsize=14, fontfamily='sans-serif',
          color=black_grad[0])
plt.pie(df['ca'].value_counts(), labels=labels, colors=colors, 
        wedgeprops=dict(alpha=0.8, edgecolor=black_grad[1]), 
        autopct='%.2f%%', pctdistance=0.7, textprops={'fontsize':12})

centre=plt.Circle((0, 0), 0.45, fc='white', edgecolor=black_grad[1])
plt.gcf().gca().add_artist(centre)

# --- Histogram ---
countplt = plt.subplot(1, 2, 2)
plt.title('Histogram', fontweight='bold', fontsize=14, fontfamily='sans-serif', 
          color=black_grad[0])
ax = sns.countplot(x='ca', data=df, palette=colors, order=order,
                   edgecolor=black_grad[2], alpha=0.85)
for rect in ax.patches:
    ax.text (rect.get_x()+rect.get_width()/2, 
             rect.get_height()+4.25,rect.get_height(), 
             horizontalalignment='center', fontsize=10,
             bbox=dict(facecolor='none', edgecolor=black_grad[0], linewidth=0.25,
                       boxstyle='round'))

plt.xlabel('Number of Major Vessels', fontweight='bold', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])
plt.ylabel('Total', fontweight='bold', fontsize=11, fontfamily='sans-serif', 
           color=black_grad[1])
plt.grid(axis='y', alpha=0.4)
countplt

# --- Count Categorical Labels w/out Dropping Null Walues ---
print('*' * 40)
print('\033[1m'+'.: Number of Major Vessels Total :.'+'\033[0m')
print('*' * 40)
df.ca.value_counts(dropna=False)
# Out:
# ****************************************
# .: Number of Major Vessels Total :.
# ****************************************
# 0    1088
# 1     414
# 2     243
# 3     128
# 4      28
# Name: ca, dtype: int64

# %% [markdown]
# ### <div style="font-family: Trebuchet MS; background-color: #FF5C8A; color: #FFFFFF; padding: 12px; line-height: 1.5;"> thal</div>

# %%
# --- Setting Colors, Labels, Order ---
colors=red_grad[0:4]
labels=['2', '3', '1', '0']
order=df['thal'].value_counts().index

# --- Size for Both Figures ---
plt.figure(figsize=(16,8))
plt.suptitle('"thal" Distribution', fontweight='heavy', fontsize=16, 
             fontfamily='sans-serif', color=black_grad[0])


# --- Histogram ---
countplt = plt.subplot(1, 2, 2)
plt.title('Histogram', fontweight='bold', fontsize=14, fontfamily='sans-serif', 
          color=black_grad[0])
ax = sns.countplot(x='thal', data=df, palette=colors, order=order,
                   edgecolor=black_grad[2], alpha=0.85)
for rect in ax.patches:
    ax.text (rect.get_x()+rect.get_width()/2, 
             rect.get_height()+4.25,rect.get_height(), 
             horizontalalignment='center', fontsize=10,
             bbox=dict(facecolor='none', edgecolor=black_grad[0], linewidth=0.25,
                       boxstyle='round'))

plt.xlabel('Number of "thal"', fontweight='bold', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])
plt.ylabel('Total', fontweight='bold', fontsize=11, fontfamily='sans-serif', 
           color=black_grad[1])
plt.grid(axis='y', alpha=0.4)
countplt

# --- Count Categorical Labels w/out Dropping Null Walues ---
print('*' * 20)
print('\033[1m'+'.: "thal" Total :.'+'\033[0m')
print('*' * 20)
df.thal.value_counts(dropna=False)
# Out:
# ********************
# .: "thal" Total :.
# ********************
# 2    876
# 3    796
# 7    104
# 1    100
# 6     14
# 0     11
# Name: thal, dtype: int64

# %% [markdown]
# ### <div style="font-family: Trebuchet MS; background-color: #FF5C8A; color: #FFFFFF; padding: 12px; line-height: 1.5;"> target (Heart Diseases Status)</div>

# %%
# --- Setting Colors, Labels, Order ---
colors=color_mix[3:5]
labels=['True', 'False']
order=df['target'].value_counts().index

# --- Size for Both Figures ---
plt.figure(figsize=(16,8))
plt.suptitle('Heart Diseases Distribution', fontweight='heavy', 
             fontsize=16, fontfamily='sans-serif', color=black_grad[0])



# --- Histogram ---
countplt = plt.subplot(1, 2, 2)
plt.title('Histogram', fontweight='bold', fontsize=14, fontfamily='sans-serif', 
          color=black_grad[0])
ax = sns.countplot(x='target', data=df, palette=colors, order=order,
                   edgecolor=black_grad[2], alpha=0.85)
for rect in ax.patches:
    ax.text (rect.get_x()+rect.get_width()/2, 
             rect.get_height()+4.25,rect.get_height(), 
             horizontalalignment='center', fontsize=10,
             bbox=dict(facecolor='none', edgecolor=black_grad[0], linewidth=0.25,
                       boxstyle='round'))

plt.xlabel('Heart Disease Status', fontweight='bold', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])
plt.ylabel('Total', fontweight='bold', fontsize=11, fontfamily='sans-serif', 
           color=black_grad[1])
plt.xticks([0, 1], labels)
plt.grid(axis='y', alpha=0.4)
countplt

# --- Count Categorical Labels w/out Dropping Null Walues ---
print('*' * 45)
print('\033[1m'+'.: Heart Diseases Status (target) Total :.'+'\033[0m')
print('*' * 45)
df.target.value_counts(dropna=False)
# Out:
# *********************************************
# .: Heart Diseases Status (target) Total :.
# *********************************************
# 1    1006
# 0     775
# 2     120
# Name: target, dtype: int64

# %% [markdown]
# ## <div style="font-family: Trebuchet MS; background-color: #BA1141; color: #FFFFFF; padding: 12px; line-height: 1.5;"> Numerical Variable 🔢</div>
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#     👉 The second variable that will be explored is <b>numerical variable</b>.
# </div>

# %% [markdown]
# ### <div style="font-family: Trebuchet MS; background-color: #FF5C8A; color: #FFFFFF; padding: 12px; line-height: 1.5;"> Descriptive Statistics 📏</div>
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#     👉 This section will show <b>descriptive statistics</b> of numerical variables.
# </div>

# %%
# --- Descriptive Statistics ---
df.select_dtypes(exclude='object').describe().T.style.background_gradient(cmap='PuRd').set_properties(**{'font-family': 'Segoe UI'})
# Out:
# <style type="text/css">
# #T_02c00_row0_col0, #T_02c00_row1_col0, #T_02c00_row2_col0, #T_02c00_row3_col0, #T_02c00_row4_col0, #T_02c00_row4_col1, #T_02c00_row4_col3, #T_02c00_row4_col4, #T_02c00_row4_col5, #T_02c00_row4_col6, #T_02c00_row5_col0, #T_02c00_row5_col1, #T_02c00_row5_col2, #T_02c00_row5_col3, #T_02c00_row5_col4, #T_02c00_row5_col6, #T_02c00_row5_col7 {
#   background-color: #f7f4f9;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T
000000</td>
#     </tr>
#     <tr>
#       <th id="T_02c00_level0_row3" class="row_heading level0 row3" >thalach</th>
#       <td id="T_02c00_row3_col0" class="data row3 col0" >1901.000000</td>
#       <td id="T_02c00_row3_col1" class="data row3 col1" >149.364019</td>
#       <td id="T_02c00_row3_col2" class="data row3 col2" >22.979970</td>
#       <td id="T_02c00_row3_col3" class="data row3 col3" >71.000000</td>
#       <td id="T_02c00_row3_col4" class="data row3 col4" >133.000000</td>
#       <td id="T_02c00_row3_col5" class="data row3 col5" >152.000000</td>
#       <td id="T_02c00_row3_col6" class="data row3 col6" >166.000000</td>
#       <td id="T_02c00_row3_col7" class="data row3 col7" >202.000000</td>
#     </tr>
#     <tr>
#       <th id="T_02c00_level0_row4" class="row_heading level0 row4" >oldpeak</th>
#       <td id="T_02c00_row4_col0" class="data row4 col0" >1901.000000</td>
#       <td id="T_02c00_row4_col1" class="data row4 col1" >0.782220</td>
#       <td id="T_02c00_row4_col2" class="data row4 col2" >1.075527</td>
#       <td id="T_02c00_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_02c00_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_02c00_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_02c00_row4_col6" class="data row4 col6" >1.000000</td>
#       <td id="T_02c00_row4_col7" class="data row4 col7" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_02c00_level0_row5" class="row_heading level0 row5" >target</th>
#       <td id="T_02c00_row5_col0" class="data row5 col0" >1901.000000</td>
#       <td id="T_02c00_row5_col1" class="data row5 col1" >0.655445</td>
#       <td id="T_02c00_row5_col2" class="data row5 col2" >0.593525</td>
#       <td id="T_02c00_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_02c00_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_02c00_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_02c00_row5_col6" class="data row5 col6" >1.000000</td>
#       <td id="T_02c00_row5_col7" class="data row5 col7" >2.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### <div style="font-family: Trebuchet MS; background-color: #FF5C8A; color: #FFFFFF; padding: 12px; line-height: 1.5;"> Continuous Column Distribution 📈</div>
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#     👉 This section will show the <b>distribution of numerical variables</b> in histograms, boxplots, Q-Q Plots, skewness and kurtosis values.
# </div>

# %%
# --- Variable, Color & Plot Size ---
var = 'age'
color = color_mix[0]
fig=plt.figure(figsize=(12, 12))

# --- Skewness & Kurtosis ---
print('\033[1m'+'.: Age Column Skewness & Kurtosis :.'+'\033[0m')
print('*' * 40)
print('Skewness:'+'\033[1m {:.3f}'.format(df[var].skew(axis = 0, skipna = True)))
print('\033[0m'+'Kurtosis:'+'\033[1m {:.3f}'.format(df[var].kurt(axis = 0, skipna = True)))
print('\n')

# --- General Title ---
fig.suptitle('Age Column Distribution', fontweight='bold', fontsize=16, 
             fontfamily='sans-serif', color=black_grad[0])
fig.subplots_adjust(top=0.9)

# --- Q-Q Plot ---
ax_2=fig.add_subplot(2, 2, 4)
plt.title('Q-Q Plot', fontweight='bold', fontsize=14, 
          fontfamily='sans-serif', color=black_grad[1])
qqplot(df[var], fit=True, line='45', ax=ax_2, markerfacecolor=color, 
       markeredgecolor=color, alpha=0.6)
plt.xlabel('Theoritical Quantiles', fontweight='regular', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])
plt.ylabel('Sample Quantiles', fontweight='regular', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])

# --- Box Plot ---
ax_3=fig.add_subplot(1, 2, 1)
plt.title('Box Plot', fontweight='bold', fontsize=14, fontfamily='sans-serif', 
          color=black_grad[1])
sns.boxplot(data=df, y=var, color=color, boxprops=dict(alpha=0.8), linewidth=1.5)
plt.ylabel('Age', fontweight='regular', fontsize=11, fontfamily='sans-serif', 
           color=black_grad[1])

plt.show()
# Out:
# .: Age Column Skewness & Kurtosis :.
# ****************************************
# Skewness: -0.221
# Kurtosis: -0.539

# %% [markdown]
# #### <h4 style="font-family: Trebuchet MS; background-color: #FF99B9; color: #FFFFFF; padding: 12px; line-height: 1.5;">  trestbps (Resting Blood Pressure in mm Hg) </h4>

# %%
# --- Variable, Color & Plot Size ---
var = 'trestbps'
color = color_mix[2]
fig=plt.figure(figsize=(12, 12))

# --- Skewness & Kurtosis ---
print('\033[1m'+'.: Resting Blood Pressure Column Skewness & Kurtosis :.'+'\033[0m')
print('*' * 55)
print('Skewness:'+'\033[1m {:.3f}'.format(df[var].skew(axis = 0, skipna = True)))
print('\033[0m'+'Kurtosis:'+'\033[1m {:.3f}'.format(df[var].kurt(axis = 0, skipna = True)))
print('\n')

# --- General Title ---
fig.suptitle('Resting Blood Pressure Column Distribution', fontweight='bold', 
             fontsize=16, fontfamily='sans-serif', color=black_grad[0])
fig.subplots_adjust(top=0.9)





# --- Box Plot ---
ax_3=fig.add_subplot(1, 2, 1)
plt.title('Box Plot', fontweight='bold', fontsize=14, fontfamily='sans-serif', 
          color=black_grad[1])
sns.boxplot(data=df, y=var, color=color, boxprops=dict(alpha=0.8), linewidth=1.5)
plt.ylabel('Resting Blood Pressure', fontweight='regular', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])

plt.show()
# Out:
# .: Resting Blood Pressure Column Skewness & Kurtosis :.
# *******************************************************
# Skewness: 0.727
# Kurtosis: 0.945

# %% [markdown]
# #### <h4 style="font-family: Trebuchet MS; background-color: #FF99B9; color: #FFFFFF; padding: 12px; line-height: 1.5;">  chol (Serum Cholestoral in mg/dl) </h4>

# %%
# --- Variable, Color & Plot Size ---
var = 'chol'
color = color_mix[4]
fig=plt.figure(figsize=(12, 12))

# --- Skewness & Kurtosis ---
print('\033[1m'+'.: Serum Cholestoral Column Skewness & Kurtosis :.'+'\033[0m')
print('*' * 45)
print('Skewness:'+'\033[1m {:.3f}'.format(df[var].skew(axis = 0, skipna = True)))
print('\033[0m'+'Kurtosis:'+'\033[1m {:.3f}'.format(df[var].kurt(axis = 0, skipna = True)))
print('\n')

# --- General Title ---
fig.suptitle('Serum Cholestoral Column Distribution', fontweight='bold', 
             fontsize=16, fontfamily='sans-serif', color=black_grad[0])
fig.subplots_adjust(top=0.9)



# --- Box Plot ---
ax_3=fig.add_subplot(1, 2, 1)
plt.title('Box Plot', fontweight='bold', fontsize=14, 
          fontfamily='sans-serif', color=black_grad[1])
sns.boxplot(data=df, y=var, color=color, boxprops=dict(alpha=0.8), linewidth=1.5)
plt.ylabel('Serum Cholestoral', fontweight='regular', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])

plt.show()
# Out:
# .: Serum Cholestoral Column Skewness & Kurtosis :.
# *********************************************
# Skewness: 1.108
# Kurtosis: 4.240

# %% [markdown]
# #### <h4 style="font-family: Trebuchet MS; background-color: #FF99B9; color: #FFFFFF; padding: 12px; line-height: 1.5;">  thalach (Maximum Heart Rate) </h4>

# %%
# --- Variable, Color & Plot Size ---
var = 'thalach'
color = purple_grad[1]
fig=plt.figure(figsize=(12, 12))

# --- Skewness & Kurtosis ---
print('\033[1m'+'.: Maximum Heart Rate Column Skewness & Kurtosis :.'+'\033[0m')
print('*' * 50)
print('Skewness:'+'\033[1m {:.3f}'.format(df[var].skew(axis = 0, skipna = True)))
print('\033[0m'+'Kurtosis:'+'\033[1m {:.3f}'.format(df[var].kurt(axis = 0, skipna = True)))
print('\n')

# --- General Title ---
fig.suptitle('Maximum Heart Rate Column Distribution', fontweight='bold', 
             fontsize=16, fontfamily='sans-serif', color=black_grad[0])
fig.subplots_adjust(top=0.9)





# --- Box Plot ---
ax_3=fig.add_subplot(1, 2, 1)
plt.title('Box Plot', fontweight='bold', fontsize=14, 
          fontfamily='sans-serif', color=black_grad[1])
sns.boxplot(data=df, y=var, color=color, boxprops=dict(alpha=0.8), linewidth=1.5)
plt.ylabel('Maximum Heart Rate', fontweight='regular', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])

plt.show()
# Out:
# .: Maximum Heart Rate Column Skewness & Kurtosis :.
# **************************************************
# Skewness: -0.522
# Kurtosis: -0.092

# %% [markdown]
# #### <h4 style="font-family: Trebuchet MS; background-color: #FF99B9; color: #FFFFFF; padding: 12px; line-height: 1.5;"> oldpeak </h4>

# %%
# --- Variable, Color & Plot Size ---
var = 'oldpeak'
color = red_grad[1]
fig=plt.figure(figsize=(12, 12))

# --- Skewness & Kurtosis ---
print('\033[1m'+'.: "oldpeak" Column Skewness & Kurtosis :.'+'\033[0m')
print('*' * 40)
print('Skewness:'+'\033[1m {:.3f}'.format(df[var].skew(axis = 0, skipna = True)))
print('\033[0m'+'Kurtosis:'+'\033[1m {:.3f}'.format(df[var].kurt(axis = 0, skipna = True)))
print('\n')

# --- General Title ---
fig.suptitle('"oldpeak" Column Distribution', fontweight='bold', 
             fontsize=16, fontfamily='sans-serif', color=black_grad[0])
fig.subplots_adjust(top=0.9)



# --- Box Plot ---
ax_3=fig.add_subplot(1, 2, 1)
plt.title('Box Plot', fontweight='bold', fontsize=14, 
          fontfamily='sans-serif', color=black_grad[1])
sns.boxplot(data=df, y=var, color=color, boxprops=dict(alpha=0.8), linewidth=1.5)
plt.ylabel('oldpeak', fontweight='regular', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])

plt.show()
# Out:
# .: "oldpeak" Column Skewness & Kurtosis :.
# ****************************************
# Skewness: 1.590
# Kurtosis: 2.624

# %% [markdown]
# # <div style="font-family: Trebuchet MS; background-color: #8A0030; color: #FFFFFF; padding: 12px; line-height: 1.5;"> EDA 📉</div>
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#     👉 This section will perform some <b>EDA</b> to get more insights about dataset.

# %% [markdown]
# ## <div style="font-family: Trebuchet MS; background-color: #BA1141; color: #FFFFFF; padding: 12px; line-height: 1.5;"> Heart Disease Distribution based on Gender 💉👫</div>
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
# 👉 This section will show heart disease distribution based on gender.
# </div>

# %%
# --- Labels Settings ---
labels = ['False', 'True']
label_gender = np.array([0, 1])
label_gender2 = ['Male', 'Female']

# --- Creating Bar Chart ---
ax = pd.crosstab(df.sex, df.target).plot(kind='bar', figsize=(8, 5), 
                                         color=color_mix[2:4], 
                                         edgecolor=black_grad[2], alpha=0.85)
# --- Bar Chart Settings ---
for rect in ax.patches:
    ax.text (rect.get_x()+rect.get_width()/2, 
             rect.get_height()+1.25,rect.get_height(), 
             horizontalalignment='center', fontsize=10)

plt.suptitle('Heart Disease Distribution based on Gender', fontweight='heavy', 
             x=0.065, y=0.98, ha='left', fontsize='16', fontfamily='sans-serif', 
             color=black_grad[0])
plt.title('Female tend to have heart diseases compared to Male. In male, the distribution is not imbalanced compared to female\nthat have almost the same distribution', 
          fontsize='8', fontfamily='sans-serif', loc='left', color=black_grad[1])
plt.tight_layout(rect=[0, 0.04, 1, 1.025])
plt.xlabel('Gender (Sex)', fontfamily='sans-serif', fontweight='bold', 
           color=black_grad[1])
plt.ylabel('Total', fontfamily='sans-serif', fontweight='bold', 
           color=black_grad[1])
plt.xticks(label_gender, label_gender2, rotation=0)
plt.grid(axis='y', alpha=0.4)
plt.grid(axis='x', alpha=0)
plt.legend(labels=labels, title='$\\bf{Target}$', fontsize='8', 
           title_fontsize='9', loc='upper left', frameon=True);

# %% [markdown]
# ## <div style="font-family: Trebuchet MS; background-color: #BA1141; color: #FFFFFF; padding: 12px; line-height: 1.5;">Heart Disease Distribution based on Major Vessels Total 💉💖</div>
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
# 👉 This section will show heart disease distribution based on number of major vessels.
# </div>

# %%
# --- Labels Settings ---
labels = ['False', 'True']

# --- Creating Horizontal Bar Chart ---
ax = pd.crosstab(df.ca, df.target).plot(kind='barh', figsize=(8, 5), 
                                         color=color_mix[2:4],
                                         edgecolor=black_grad[2], alpha=0.85)
# --- Horizontal Bar Chart Settings ---
for rect in ax.patches:
    width, height = rect.get_width(), rect.get_height()
    x, y = rect.get_xy()
    ax.text (x+width/2, y+height/2, '{:.0f}'.format(width), 
             horizontalalignment='center', verticalalignment='center')

plt.suptitle('Heart Disease Distribution based on Major Vessels Total', 
             fontweight='heavy', x=0.069, y=0.98, ha='left', fontsize='16', 
             fontfamily='sans-serif', color=black_grad[0])
plt.title('Patients with 0 and 4 major vessels tend to have heart diseases. However, patients who have a number of vessels 1 to 3\ntend not to have heart diseases.', 
          fontsize='8', fontfamily='sans-serif', loc='left', color=black_grad[1])
plt.tight_layout(rect=[0, 0.04, 1, 1.025])
plt.xlabel('Total', fontfamily='sans-serif', fontweight='bold', color=black_grad[1])
plt.ylabel('Number of Major Vessels', fontfamily='sans-serif', fontweight='bold', 
           color=black_grad[1])
plt.yticks(rotation=0)
plt.grid(axis='x', alpha=0.4)
plt.grid(axis='y', alpha=0)
plt.legend(labels=labels, title='$\\bf{Target}$', fontsize='8', frameon=True,
           title_fontsize='9', loc='upper right');

# %% [markdown]
# ## <div style="font-family: Trebuchet MS; background-color: #BA1141; color: #FFFFFF; padding: 12px; line-height: 1.5;"> Heart Disease Scatter Plot based on Age </div>
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
# 👉 This section will show <b>scatter plot</b> of patients with heart diseases based on age.
# </div>

# %%
# -- Scatter Plot Size & Titles Settings ---
plt.figure(figsize=(10, 8))
plt.suptitle('Heart Disease Scatter Plot based on Age', fontweight='heavy', 
             x=0.048, y=0.98, ha='left', fontsize='16', fontfamily='sans-serif', 
             color=black_grad[0])
plt.title('Based on age, patients with and without heart diseases mostly between 50-70 years old. Patients with heart diseases tend to have high heart rate\ncompared to patients with no heart diseases.', 
          fontsize='8', fontfamily='sans-serif', loc='left', color=black_grad[1])
plt.tight_layout(rect=[0, 0.04, 1, 1.01])

# --- Creating Scatter Plot ---
plt.scatter(x=df.age[df.target==0], y=df.thalach[(df.target==0)], c=pink_grad[0])
plt.scatter(x=df.age[df.target==1], y=df.thalach[(df.target==1)], c=pink_grad[2])

# --- Scatter Plot Legend & Labels Settings ---
plt.legend(['False', 'True'], title='$\\bf{Type}$', fontsize='7', 
           title_fontsize='8', loc='upper right', frameon=True)
plt.xlabel('Age', fontweight='bold', fontsize='11',
           fontfamily='sans-serif', color=black_grad[1])
plt.ylabel('Max. Heart Rate', fontweight='bold', fontsize='11', 
           fontfamily='sans-serif', color=black_grad[1])
plt.ticklabel_format(style='plain', axis='both')
plt.grid(axis='both', alpha=0.4, lw=0.5)
plt.show();

# %% [markdown]
# ## <div style="font-family: Trebuchet MS; background-color: #BA1141; color: #FFFFFF; padding: 12px; line-height: 1.5;"> Heatmap 🔥</div>
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#     👉 Below is <b>correlation map/heatmap of numerical variables</b> to show correlation level/values for each variables with others.
# </div>

# %%
# --- Correlation Map (Heatmap) ---
plt.figure(figsize=(14, 9))
sns.heatmap(df.corr(), annot=True, cmap='bone', linewidths=0.1)
plt.suptitle('Correlation Map of Numerical Variables', fontweight='heavy', 
             x=0.03, y=0.98, ha='left', fontsize='16', fontfamily='sans-serif', 
             color=black_grad[0])
plt.title('Resting blood pressure, cholestoral, and "oldpeak" have moderate relationship with age.', 
          fontsize='10', fontfamily='sans-serif', loc='left', color=black_grad[1])
plt.tight_layout(rect=[0, 0.04, 1, 1.01])

# %% [markdown]
# # <div style="font-family: Trebuchet MS; background-color: #BA1141; color: #FFFFFF; padding: 12px; line-height: 1.5;"> Dataset Pre-processing ⚙</div>
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#     👉 This section will <b>prepare the dataset</b> before building the machine learning models.
# </div>

# %% [markdown]
# ## <div style="font-family: Trebuchet MS; background-color: #FF5C8A; color: #FFFFFF; padding: 12px; line-height: 1.5;"> One-Hot Encoding 🔧</div>
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#     👉 The data pre-processing will be transforming categorical variables using <b>one-hot encoding technique</b>.
# </div>

# %%
# --- Creating Dummy Variables for cp, thal and slope ---
cp = pd.get_dummies(df['cp'], prefix='cp')
thal = pd.get_dummies(df['thal'], prefix='thal')
slope = pd.get_dummies(df['slope'], prefix='slope')

# --- Merge Dummy Variables to Main Data Frame ---
frames = [df, cp, thal, slope]
df = pd.concat(frames, axis = 1)

# %%
# --- Display New Data Frame ---
df.head().style.background_gradient(cmap='PuRd').hide_index().set_properties(**{'font-family': 'Segoe UI'})
# Out:
# <style type="text/css">
# #T_9b04c_row0_col0, #T_9b04c_row0_col3, #T_9b04c_row0_col13, #T_9b04c_row0_col14, #T_9b04c_row0_col15, #T_9b04c_row0_col16, #T_9b04c_row0_col17, #T_9b04c_row0_col18, #T_9b04c_row0_col19, #T_9b04c_row0_col20, #T_9b04c_row0_col21, #T_9b04c_row0_col23, #T_9b04c_row0_col24, #T_9b04c_row0_col25, #T_9b04c_row0_col26, #T_9b04c_row0_col28, #T_9b04c_row1_col13, #T_9b04c_row1_col14, #T_9b04c_row1_col15, #T_9b04c_row1_col16, #T_9b04c_row1_col17, #T_9b04c_row1_col18, #T_9b04c_row1_col19, #T_9b04c_row1_col20, #T_9b04c_row1_col21, #T_9b04c_row1_col23, #T_9b04c

#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_9b04c_row1_col0 {
#   background-color: #f0ecf5;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_9b04c_row1_col3 {
#   background-color: #e2247f;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_9b04c_row1_col4, #T_9b04c_row3_col4 {
#   background-color: #d6bcdc;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_9b04c_row1_col7 {
#   background-color: #bc0c50;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_9b04c_row2_col3 {
#   background-color: #9a0144;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_9b04c_row2_col7 {
#   background-color: #cfa8d2;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_9b04c_row2_col9 {
#   background-color: #df2179;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_9b04c_row3_col0 {
#   background-color: #df64af;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_9b04c_row3_col7 {
#   background-color: #92003f;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_9b04c_row4_col0 {
#   background-color: #e34a9f;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_9b04c_row4_col3 {
#   background-color: #e3469c;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_9b04c_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >age</th>
#       <th class="col_heading level0 col1" >sex</th>
#       <th class="col_heading level0 col2" >cp</th>
#       <th class="col_heading level0 col3" >trestbps</th>
#       <th class="col_heading level0 col4" >chol</th>
#       <th class="col_heading level0 col5" >fbs</th>
#       <th class="col_heading level0 col6" >restecg</th>
#       <th class="col_heading level0 col7" >thalach</th>
#       <th class="col_heading level0 col8" >exang</th>
#       <th class="col_heading level0 col9" >oldpeak</th>
#       <th class="col_heading level0 col10" >slope</th>
#       <th class="col_heading level0 col11" >ca</th>
#       <th class="col_heading level0 col12" >thal</th>
#       <th class="col_heading level0 col13" >target</th>
#       <th class="col_heading level0 col14" >cp_0</th>
#       <th class="col_heading level0 col15" >cp_1</th>
#       <th class="col_heading level0 col16" >cp_2</th>
#       <th class="col_heading level0 col17" >cp_3</th>
#       <th class="col_heading level0 col18" >cp_4</th>
#       <th class="col_heading level0 col19" >thal_0</th>
#       <th class="col_heading level0 col20" >thal_1</th>
#       <th class="col_heading level0 col21" >thal_2</th>
#       <th class="col_heading level0 col22" >thal_3</th>
#       <th class="col_heading level0 col23" >thal_6</th>
#       <th class="col_heading level0 col24" >thal_7</th>
#       <th class="col_heading level0 col25" >slope_0</th>
#       <th class="col_heading level0 col26" >slope_1</th>
#       <th class="col_heading level0 col27" >slope_2</th>
#       <th class="col_heading level0 col28" >slope_3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9b04c_row0_col0" class="data row0 col0" >52</td>
#       <td id="T_9b04c_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_9b04c_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_9b04c_row0_col3" class="data row0 col3" >125</td>
#       <td id="T_9b04c_row0_col4" class="data row0 col4" >212</td>
#       <td id="T_9b04c_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_9b04c_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_9b04c_row0_col7" class="data row0 col7" >168</td>
#       <td id="T_9b04c_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_9b04c_row0_col9" class="data row0 col9" >1</td>
#       <td id="T_9b04c_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_9b04c_row0_col11" class="data row0 col11" >2</td>
#       <td id="T_9b04c_row0_col12" class="data row0 col12" >3</td>
#       <td id="T_9b04c_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_9b04c_row0_col14" class="data row0 col14" >1</td>
#       <td id="T_9b04c_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_9b04c_row0_col16" class="data row0 col16" >0</td>
#       <td id="T_9b04c_row0_col17" class="data row0 col17" >0</td>
#       <td id="T_9b04c_row0_col18" class="data row0 col18" >0</td>
#       <td id="T_9b04c_row0_col19" class="data row0 col19" >0</td>
#       <td id="T_9b04c_row0_col20" class="data row0 col20" >0</td>
#       <td id="T_9b04c_row0_col21" class="data row0 col21" >0</td>
#       <td id="T_9b04c_row0_col22" class="data row0 col22" >1</td>
#       <td id="T_9b04c_row0_col23" class="data row0 col23" >0</td>
#       <td id="T_9b04c_row0_col24" class="data row0 col24" >0</td>
#       <td id="T_9b04c_row0_col25" class="data row0 col25" >0</td>
#       <td id="T_9b04c_row0_col26" class="data row0 col26" >0</td>
#       <td id="T_9b04c_row0_col27" class="data row0 col27" >1</td>
#       <td id="T_9b04c_row0_col28" class="data row0 col28" >0</td>
#     </tr>
#     <tr>
#       <td id="T_9b04c_row1_col0" class="data row1 col0" >53</td>
#       <td id="T_9b04c_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_9b04c_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_9

# %% [markdown]
# ## <div style="font-family: Trebuchet MS; background-color: #FF5C8A; color: #FFFFFF; padding: 12px; line-height: 1.5;"> Dropping Unnecessary Variables 🔻 </div>
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#     👉 The <b>variables that unnecessary will be deleted</b>.
# </div>

# %%
# --- Drop Unnecessary Variables ---
df = df.drop(columns = ['cp', 'thal', 'slope'])

# %%
# --- Display New Data Frame ---
df.head().style.background_gradient(cmap='Reds').hide_index().set_properties(**{'font-family': 'Segoe UI'})
# Out:
# <style type="text/css">
# #T_7d801_row0_col0, #T_7d801_row0_col2, #T_7d801_row0_col10, #T_7d801_row0_col11, #T_7d801_row0_col12, #T_7d801_row0_col13, #T_7d801_row0_col14, #T_7d801_row0_col15, #T_7d801_row0_col16, #T_7d801_row0_col17, #T_7d801_row0_col18, #T_7d801_row0_col20, #T_7d801_row0_col21, #T_7d801_row0_col22, #T_7d801_row0_col23, #T_7d801_row0_col25, #T_7d801_row1_col10, #T_7d801_row1_col11, #T_7d801_row1_col12, #T_7d801_row1_col13, #T_7d801_row1_col14, #T_7d801_row1_col15, #T_7d801_row1_col16, #T_7d801_row1_col17, #T_7d801_row1_col18, #T_7d801_row1_col20, #T_7d801_row1_col21, #T_7d801_row1_col23, #T_7d801_row1_col24, #T_7d801_row1_col25, #T_7d801_row2_col3, #T_7d801_row2_col10, #T_7d801_row2_col11, #T_7d801_row2_col12, #T_7d801_row2_col13, #T_7d801_row2_col14, #T_7d801_row2_col15, #T_7d801_row2_col16, #T_7d801_row2_col17, #T_7d801_row2_col18, #T_7d801_row2_col20, #T_7d801_row2_col21, #T_7d801_row2_col23, #T_7d801_row2_col24, #T_7d801_row2_col25, #T_7d801_row3_col8, #T_7d801_row3_col10, #T_7d801_row3_col11, #T_7d801_row3_col12, #T_7d801_row3_col13, #T_7d801_row3_col14, #T_7d801_row3_col15, #T_7d801_row3_col16, #T_7d801_row3_col17, #T_7d801_row3_col18, #T_7d801_row3_col20, #T_7d801_row3_col21, #T_7d801_row3_col22, #T_7d801_row3_col23, #T_7d801_row3_col25, #T_7d801_row4_col6, #T_7d801_row4_col10, #T_7d801_row4_col11, #T_7d801_row4_col12, #T_7d801_row4_col13, #T_7d801_row4_col14, #T_7d801_row4_col15, #T_7d801_row4_col16, #T_7d801_row4_col17, #T_7d801_row4_col19, #T_7d801_row4_col20, #T_7d801_row4_col21, #T_7d801_row4_col22, #T_7d801_row4_col24, #T_7d801_row4_col25 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_7d801_row0_col1, #T_7d801_row0_col4, #T_7d801_row0_col5, #T_7d801_row0_col7, #T_7d801_row0_col9, #T_7d801_row1_col1, #T_7d801_row1_col4, #T_7d801_row1_col5, #T_7d801_row1_col7, #T_7d801_row1_col9, #T_7d801_row2_col1, #T_7d801_row2_col4, #T_7d801_row2_col5, #T_7d801_row2_col7, #T_7d801_row2_col9, #T_7d801_row3_col1, #T_7d801_row3_col4, #T_7d801_row3_col5, #T_7d801_row3_col7, #T_7d801_row3_col9, #T_7d801_row4_col1, #T_7d801_row4_col4, #T_7d801_row4_col5, #T_7d801_row4_col7, #T_7d801_row4_col9 {
#   font-family: Segoe UI;
# }
# #T_7d801_row0_col3 {
#   background-color: #fca588;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_7d801_row0_col6, #T_7d801_row0_col19, #T_7d801_row0_col24, #T_7d801_row1_col8, #T_7d801_row1_col19, #T_7d801_row1_col22, #T_7d801_row2_col0, #T_7d801_row2_col19, #T_7d801_row2_col22, #T_7d801_row3_col2, #T_7d801_row3_col19, #T_7d801_row3_col24, #T_7d801_row4_col3, #T_7d801_row4_col18, #T_7d801_row4_col23 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_7d801_row0_col8, #T_7d801_row4_col8 {
#   background-color: #fca082;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_7d801_row1_col0 {
#   background-color: #ffece3;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_7d801_row1_col2 {
#   background-color: #e83429;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_7d801_row1_col3, #T_7d801_row3_col3 {
#   background-color: #fcbea5;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_7d801_row1_col6 {
#   background-color: #be151a;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_7d801_row2_col2 {
#   background-color: #a60f15;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_7d801_row2_col6 {
#   background-color: #fca98c;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_7d801_row2_col8 {
#   background-color: #e32f27;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_7d801_row3_col0 {
#   background-color: #fb694a;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_7d801_row3_col6 {
#   background-color: #9d0d14;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_7d801_row4_col0 {
#   background-color: #f6553c;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_7d801_row4_col2 {
#   background-color: #f5523a;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_7d801_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >age</th>
#       <th class="col_heading level0 col1" >sex</th>
#       <th class="col_heading level0 col2" >trestbps</th>
#       <th class="col_heading level0 col3" >chol</th>
#       <th class="col_heading level0 col4" >fbs</th>
#       <th class="col_heading level0 col5" >restecg</th>
#       <th class="col_heading level0 col6" >thalach</th>
#       <th class="col_heading level0 col7" >exang</th>
#       <th class="col_heading level0 col8" >oldpeak</th>
#       <th class="col_heading level0 col9" >ca</th>
#       <th class="col_heading level0 col10" >target</th>
#       <th class="col_heading level0 col11" >cp_0</th>
#       <th class="col_heading level0 col12" >cp_1</th>
#       <th class="col_heading level0 col13" >cp_2</th>
#       <th class="col_heading level0 col14" >cp_3</th>
#       <th class="col_heading level0 col15" >cp_4</th>
#       <th class="col_heading level0 col16" >thal_0</th>
#       <th class="col_heading level0 col17" >thal_1</th>
#       <th class="col_heading level0 col18" >thal_2</th>
#       <th class="col_heading level0 col19" >thal_3</th>
#       <th class="col_heading level0 col20" >thal_6</th>
#       <th class="col_heading level0 col21" >thal_7</th>
#       <th class="col_heading level0 col22" >slope_0</th>
#       <th class="col_heading level0 col23" >slope_1</th>
#       <th class="col_heading level0 col24" >slope_2</th>
#       <th class="col_heading level0 col25" >slope_3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7d801_row0_col0" class="data row0 col0" >52</td>
#       <td id="T_7d801_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_7d801_row0_col2" class="data row0 col2" >125</td>
#       <td id="T_7d801_row0_col3" class="data row0 col3" >212</td>
#       <td id="T_7d801_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_7d801_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_7d801_row0_col6" class="data row0 col6" >168</td>
#       <td id="T_7d801_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_7d801_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_7d801_row0_col9" class="data row0 col9" >2</td>
#       <td id="T_7d801_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_7d801_row0_col11" class="data row0 col11" >1</td>
#       <td id="T_7d801_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_7d801_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_7d801_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_7d801_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_7d801_row0_col16" class="data row0 col16" >0</td>
#       <td id="T_7d801_row0_col17" class="data row0 col17" >0</td>
#       <td id="T_7d801_row0_col18" class="data row0 col18" >0</td>
#       <td id="T_7d801_row0_col19" class="data row0 col19" >1</td>
#       <td id="T_7d801_row0_col20" class="data row0 col20" >0</td>
#       <td id="T_7d801_row0_col21" class="data row0 col21" >0</td>
#       <td id="T_7d801_row0_col22" class="data row0 col22" >0</td>
#       <td id="T_7d801_row0_col23" class="data row0 col23" >0</td>
#       <td id="T_7d801_row0_col24" class="data row0 col24" >1</td>
#       <td id="T_7d801_row0_col25" class="data row0 col25" >0</td>
#     </tr>
#     <tr>
#       <td id="T_7d801_row1_col0" class="data row1 col0" >53</td>
#       <td id="T_7d801_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_7d801_row1_col2" class="data row1 col2" >140</td>
#       <td id="T_7d801_row1_col3" class="data row1 col3" >203</td>
#       <td id="T_7d801_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_7d801_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_7d801_row1_col6" class="data row1 col6" >155</td>
#       <td id="T_7d801_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_7d801_row1_col8" class="data row1 col8" >3</td>
#       <td id="T_7d801_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_7d801_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_7d801_row1_col11" class="data row1 col11" >1</td>
#       <td id="T_7d801_row1_col12" class="data row1 col12" >0</td>
#       <td id="T_7d801_row1_col13" class

# %% [markdown]
# ## <div style="font-family: Trebuchet MS; background-color: #FF5C8A; color: #FFFFFF; padding: 12px; line-height: 1.5;">eatures Separating ➗</div>
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#     👉 In this section, <mark><b>the 'target' (dependent) column will be seperated</b></mark> from independent columns.
# </div>

# %%
# --- Seperating Dependent Features ---
x = df.drop(['target'], axis=1)
y = df['target']

# %% [markdown]
# ## <div style="font-family: Trebuchet MS; background-color: #FF5C8A; color: #FFFFFF; padding: 12px; line-height: 1.5;"> Data Normalization ⚖</div>
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#     👉 In this section, data normalization will be performed to <mark><b>normalize the range of independent variables</b></mark> or features of data.<br>
#     👉 Data normalization will use <mark><b>min-max normalization</b></mark>.
#     <blockquote style="font-size: 12px; color: #000000;">
#     📌 <b>Min-max normalization</b> is often known as feature scaling where <mark><b>the values of a numeric range of a feature of data, are reduced to a scale between 0 and 1</b></mark>.
#     </blockquote>
# </div>

# %%
# --- Data Normalization using Min-Max Method ---
x = MinMaxScaler().fit_transform(x)

# %% [markdown]
# ## <div style="font-family: Trebuchet MS; background-color: #FF5C8A; color: #FFFFFF; padding: 12px; line-height: 1.5;"> Splitting the Dataset 🪓</div>
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#     👉 The dataset will be splitted into <mark><b>80:20 ratio</b></mark> (80% training and 20% testing).
# </div>

# %%
# --- Splitting Dataset into 80:20 ---
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=4)

# %% [markdown]
# # <div style="font-family: Trebuchet MS; background-color: #BA1141; color: #FFFFFF; padding: 12px; line-height: 1.5;">Model Implementation 🛠</div>
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#     👉 This section will implement various machine learning models as mentioned in <b>Introduction</b> section. In addition, explanation for each models will be discussed.
# </div>

# %% [markdown]
# ## <div style="font-family: Trebuchet MS; background-color: #FF5C8A; color: #FFFFFF; padding: 12px; line-height: 1.5;"> Logistic Regression</div>
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#     <blockquote style="color: #000000;">
#     <mark><b>Logistic regression</b></mark> is a statistical method that is used for building machine learning models where <b>the dependent variable is dichotomous: i.e. binary</b>. Logistic regression is used to describe data and <b>the relationship between one dependent variable and one or more independent variables</b>. The independent variables can be nominal, ordinal, or of interval type.<br><br>
#     The name "logistic regression" is derived from the concept of the logistic function that it uses. <b>The logistic function is also known as the sigmoid function</b>. The value of this logistic function lies between zero and one.<br><br>
#     <center>
#     <img src="https://www.simplilearn.com/ice9/free_resources_article_thumb/years-2.JPG" alt="Logistic Regression" width="40%"><br>
#     <i>🖼 Logistic Function by Simplilearn</i>
#     </center>
#     </blockquote>
# </div>

# %%
# --- Applying Logistic Regression ---
LRclassifier = LogisticRegression(max_iter=1000, random_state=1, solver='liblinear', penalty='l1')
LRclassifier.fit(x_train, y_train)

y_pred_LR = LRclassifier.predict(x_test)

# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:8px;
#             background-color:#2b2b2b;
#             font-size:120%;
#             font-family:sans-serif;
#             letter-spacing:0.5px">
#     <p style="padding: 8px;color:white;"><b>👉 | Logistic Regression -84% acc</b></p>
# </div>

# %%
# --- LR Accuracy ---
LRAcc = accuracy_score(y_pred_LR, y_test)
print('.:. Logistic Regression Accuracy:'+'\033[1m {:.2f}%'.format(LRAcc*100)+' .:.')
# Out:
# .:. Logistic Regression Accuracy: 87.66% .:.

# %% [markdown]
# ## <div style="font-family: Trebuchet MS; background-color: #FF5C8A; color: #FFFFFF; padding: 12px; line-height: 1.5;"> K-Nearest Neighbour (KNN)</div>
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#     <blockquote style="color: #000000;">
#     <mark><b>The k-nearest neighbors (KNN)</b></mark> algorithm is a data classification method <b>for estimating the likelihood that a data point will become a member of one group or another</b> based on what group the data points nearest to it belong to.<br><br>
#     The k-nearest neighbor algorithm is a type of supervised machine learning algorithm used <b>to solve classification and regression problems</b>.<br><br>
#     It's called a <b>lazy learning algorithm or lazy learner</b> because it doesn't perform any training when you supply the training data. Instead, it just stores the data during the training time and doesn't perform any calculations. It doesn't build a model until a query is performed on the dataset. This makes KNN ideal for data mining.</b></mark>.<br><br>
#     <center>
#     <img src="https://1.bp.blogspot.com/-D6REhf2XBwQ/XZcWn0cwSEI/AAAAAAAAAvs/LUCN8jxvzcMjkkDK4FAXSuR7MBDW8SBJgCLcBGAsYHQ/s1600/KNN_final_a1mrv9.jpg" alt="KNN" width="35%"><br>
#     <i>🖼 KNN by Kita Informatika</i>
#     </center>
#     </blockquote>
# </div>

# %%
# --- Applying KNN ---
KNNClassifier = KNeighborsClassifier(n_neighbors=3)
KNNClassifier.fit(x_train, y_train)

y_pred_KNN = KNNClassifier.predict(x_test)
KNN_accuracy = accuracy_score(y_pred_KNN,y_test)
print(KNN_accuracy)
mat = confusion_matrix(y_test,y_pred_KNN)
fig, ax = plt.subplots(figsize=(10,10))         # Sample figsize in inches
sns.set(font_scale=1.6)
sns.heatmap(mat, annot=True, linewidths=0.25, ax=ax)
print(mat)
print(classification_report(y_test,y_pred_KNN))
# Out:
# 0.94750656167979
# [[156   0   0]
#  [  4 178  11]
#  [  1   4  27]]
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       156
#            1       0.98      0.92      0.95       193
#            2       0.71      0.84      0.77        32
#
#     accuracy                           0.95       381
#    macro avg       0.89      0.92      0.90       381
# weighted avg       0.95      0.95      0.95       381

# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:8px;
#             background-color:#2b2b2b;
#             font-size:120%;
#             font-family:sans-serif;
#             letter-spacing:0.5px">
#     <p style="padding: 8px;color:white;"><b>👉 | KNearest Neighbors - 96% acc</b></p>
# </div>

# %%
# --- KNN Accuracy ---
KNNAcc = accuracy_score(y_pred_KNN, y_test)
print('.:. K-Nearest Neighbour Accuracy:'+'\033[1m {:.2f}%'.format(KNNAcc*100)+' .:.')
# Out:
# .:. K-Nearest Neighbour Accuracy: 94.75% .:.

# %% [markdown]
# ## <div style="font-family: Trebuchet MS; background-color: #FF5C8A; color: #FFFFFF; padding: 12px; line-height: 1.5;"> Support Vector Machine (SVM)</div>
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#     <blockquote style="color: #000000;">
#     <mark><b>Support Vector Machine (SVM)</b></mark> is one of the most popular Supervised Learning algorithms, which is used for Classification as well as Regression problems.<br><br>
#     The goal of the SVM algorithm is <b>to create the best line or decision boundary that can segregate n-dimensional space into classes</b> so that we can easily put the new data point in the correct category in the future. This best decision boundary is called a hyperplane.<br><br>
#         SVM chooses the <b>extreme points/vectors</b> that help in creating the hyperplane. These extreme cases are called as support vectors, and hence algorithm is termed as Support Vector Machine.<br>
#     <center>
#     <img src="https://static.javatpoint.com/tutorial/machine-learning/images/support-vector-machine-algorithm.png" alt="SVM" width="40%"><br>
#     <i>🖼 SVM by JavaTPoint</i>
#     </center>
#     </blockquote>
# </div>

# %%
# --- Applying SVM ---
SVMclassifier = SVC(kernel='linear', max_iter=1000, C=10, probability=True)
SVMclassifier.fit(x_train, y_train)

y_pred_SVM = SVMclassifier.predict(x_test)

# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:8px;
#             background-color:#2b2b2b;
#             font-size:120%;
#             font-family:sans-serif;
#             letter-spacing:0.5px">
#     <p style="padding: 8px;color:white;"><b>👉 | SVM - 84% acc</b></p>
# </div>

# %%
# --- SVM Accuracy ---
SVMAcc = accuracy_score(y_pred_SVM, y_test)
print('.:. Support Vector Machine Accuracy:'+'\033[1m {:.2f}%'.format(SVMAcc*100)+' .:.')
# Out:
# .:. Support Vector Machine Accuracy: 85.83% .:.

# %% [markdown]
# ## <div style="font-family: Trebuchet MS; background-color: #FF5C8A; color: #FFFFFF; padding: 12px; line-height: 1.5;">Gaussian Naive Bayes</div>
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#     <blockquote style="color: #000000;">
#     <mark><b>Naive Bayes Classifiers</b></mark> are based on the Bayes Theorem, which <b>one assumption taken is the strong independence assumptions between the features</b>. These classifiers assume that the value of a particular feature is independent of the value of any other feature. In a supervised learning situation, Naive Bayes Classifiers are trained very efficiently. Naive Bayes classifiers <b>need a small training data to estimate the parameters needed for classification</b>. Naive Bayes Classifiers have simple design and implementation and they can applied to many real life situations.<br><br>
#     <mark><b>Gaussian Naive Bayes</b></mark> is a <b>variant of Naive Bayes that follows Gaussian normal distribution and supports continuous data</b>. When working with continuous data, an assumption often taken is that the continuous values associated with each class are distributed according to a normal (or Gaussian) distribution.<br>
#     <center>
#     <img src="https://iq.opengenus.org/content/images/2020/02/Illustration-of-how-a-Gaussian-Naive-Bayes-GNB-classifier-works-For-each-data-point.png" alt="GNB" width="35%"><br>
#     <i>🖼 Gaussian Naive Bayes by OpenGenus</i>
#     </center>
#     </blockquote>
# </div>

# %%
# --- Applying Gaussian NB ---
GNBclassifier = GaussianNB(var_smoothing=0.1)
GNBclassifier.fit(x_train, y_train)

y_pred_GNB = GNBclassifier.predict(x_test)

# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:8px;
#             background-color:#2b2b2b;
#             font-size:120%;
#             font-family:sans-serif;
#             letter-spacing:0.5px">
#     <p style="padding: 8px;color:white;"><b>👉 |
# Gaussian Naive Bayes - 83% acc</b></p>
# </div>

# %%
# --- GNB Accuracy ---
GNBAcc = accuracy_score(y_pred_GNB, y_test)
print('.:. Gaussian Naive Bayes Accuracy:'+'\033[1m {:.2f}%'.format(GNBAcc*100)+' .:.')
# Out:
# .:. Gaussian Naive Bayes Accuracy: 83.46% .:.

# %% [markdown]
# ## <div style="font-family: Trebuchet MS; background-color: #FF5C8A; color: #FFFFFF; padding: 12px; line-height: 1.5;"> Decision Tree</div>
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#     <blockquote style="color: #000000;">
#     <mark><b>Decision Tree</b></mark> is a Supervised learning technique that can be used for both classification and Regression problems, but mostly it is preferred for solving Classification problems. It is a tree-structured classifier, where <b>internal nodes represent the features of a dataset, branches represent the decision rules and each leaf node represents the outcome</b>.<br><br>
#     In a Decision tree, there are <b>two nodes</b>, which are the <mark><b>Decision Node and Leaf Node</b></mark>. Decision nodes are used to make any decision and have multiple branches, whereas Leaf nodes are the output of those decisions and do not contain any further branches.<br>
#     <center>
#     <img src="https://static.javatpoint.com/tutorial/machine-learning/images/decision-tree-classification-algorithm.png" alt="DT" width="35%"><br>
#     <i>🖼 Decision Tree by Javatpoint</i>
#     </center>
#     </blockquote>
# </div>

# %%
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix,classification_report

# %%
# --- Applying Decision Tree ---
DTCclassifier = DecisionTreeClassifier(max_depth=3, min_samples_leaf=5, criterion='entropy', min_samples_split=5,
                                       splitter='random', random_state=1)

DTCclassifier.fit(x_train, y_train)
y_pred_DTC = DTCclassifier.predict(x_test)
dt_accuracy = accuracy_score(y_pred_DTC,y_test)
print(dt_accuracy)
mat = confusion_matrix(y_test,y_pred_DTC)
fig, ax = plt.subplots(figsize=(10,10))         # Sample figsize in inches
sns.set(font_scale=1.6)
sns.heatmap(mat, annot=True, linewidths=0.25, ax=ax)
print(mat)
print(classification_report(y_test,y_pred_DTC))
# Out:
# 0.8398950131233596
# [[120  36   0]
#  [ 11 180   2]
#  [  0  12  20]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.77      0.84       156
#            1       0.79      0.93      0.86       193
#            2       0.91      0.62      0.74        32
#
#     accuracy                           0.84       381
#    macro avg       0.87      0.78      0.81       381
# weighted avg       0.85      0.84      0.84       381

# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:8px;
#             background-color:#2b2b2b;
#             font-size:120%;
#             font-family:sans-serif;
#             letter-spacing:0.5px">
#     <p style="padding: 8px;color:white;"><b>👉 | Decision Tree- 84% acc</b></p>
# </div>

# %%
# --- Decision Tree Accuracy ---
DTCAcc = accuracy_score(y_pred_DTC, y_test)
print('.:. Decision Tree Accuracy:'+'\033[1m {:.2f}%'.format(DTCAcc*100)+' .:.')
# Out:
# .:. Decision Tree Accuracy: 83.99% .:.

# %% [markdown]
# ## <div style="font-family: Trebuchet MS; background-color: #FF5C8A; color: #FFFFFF; padding: 12px; line-height: 1.5;">Random Forest</div>
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#     <blockquote style="color: #000000;">
#     <mark><b>Random Forest</b></mark> is a tree-based machine learning algorithm that <b>leverages the power of multiple decision trees for making decisions</b>. Each individual tree in the random forest spits out a class prediction and the class with the most votes becomes our model’s prediction. <b>A large number of relatively uncorrelated models (trees) operating as a committee will outperform any of the individual constituent models</b>.<br>
#     <center>
#     <img src="https://cdn.analyticsvidhya.com/wp-content/uploads/2020/02/rfc_vs_dt1.png" alt="RF" width="35%"><br>
#     <i>🖼 Random Forest by Abhishek Sharma</i>
#     </center>
#     </blockquote>
# </div>

# %%
# --- Applying Random Forest ---
RFclassifier = RandomForestClassifier(n_estimators=1000, random_state=1, max_leaf_nodes=20, min_samples_split=15)

RFclassifier.fit(x_train, y_train)
y_pred_RF = RFclassifier.predict(x_test)
RF_accuracy = accuracy_score(y_pred_RF,y_test)
print(RF_accuracy)
mat = confusion_matrix(y_test,y_pred_RF)
fig, ax = plt.subplots(figsize=(10,10))         # Sample figsize in inches
sns.set(font_scale=1.6)
sns.heatmap(mat, annot=True, linewidths=0.25, ax=ax)
print(mat)
print(classification_report(y_test,y_pred_RF))
# Out:
# 0.910761154855643
# [[139  17   0]
#  [  8 184   1]
#  [  0   8  24]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.89      0.92       156
#            1       0.88      0.95      0.92       193
#            2       0.96      0.75      0.84        32
#
#     accuracy                           0.91       381
#    macro avg       0.93      0.86      0.89       381
# weighted avg       0.91      0.91      0.91       381

# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:8px;
#             background-color:#2b2b2b;
#             font-size:120%;
#             font-family:sans-serif;
#             letter-spacing:0.5px">
#     <p style="padding: 8px;color:white;"><b>👉 | Random Forest - 89% acc</b></p>
# </div>

# %%
# --- Random Forest Accuracy ---
RFAcc = accuracy_score(y_pred_RF, y_test)
print('.:. Random Forest Accuracy:'+'\033[1m {:.2f}%'.format(RFAcc*100)+' .:.')
# Out:
# .:. Random Forest Accuracy: 91.08% .:.

# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:8px;
#             background-color:#2b2b2b;
#             font-size:120%;
#             font-family:sans-serif;
#             letter-spacing:0.5px">
#     <p style="padding: 8px;color:white;"><b>👉 |Gradient Boosting - 88% acc</b></p>
# </div>

# %% [markdown]
# ## <div style="font-family: Trebuchet MS; background-color: #FF5C8A; color: #FFFFFF; padding: 12px; line-height: 1.5;"> Model Comparison </div>
# <div style="font-family: Segoe UI; line-height: 2; color: #000000; text-align: justify">
#     👉 After implementing 10 models, this section will <b>compare machine learning models</b>.
# </div>

# %%
# --- Create Accuracy Comparison Table ---
compare = pd.DataFrame({'Model': ['Logistic Regression', 'K-Nearest Neighbour', 'Support Vector Machine', 
                                  'Gaussian Naive Bayes', 'Decision Tree', 'Random Forest'
                                  ], 
                        'Accuracy': [LRAcc*100, KNNAcc*100, SVMAcc*100, GNBAcc*100, DTCAcc*100, RFAcc*100 
                                     ]})

# --- Create Accuracy Comparison Table ---
compare.sort_values(by='Accuracy', ascending=False).style.background_gradient(cmap='PuRd').hide_index().set_properties(**{'font-family': 'Segoe UI'})
# Out:
# <style type="text/css">
# #T_83e89_row0_col0, #T_83e89_row1_col0, #T_83e89_row2_col0, #T_83e89_row3_col0, #T_83e89_row4_col0, #T_83e89_row5_col0 {
#   font-family: Segoe UI;
# }
# #T_83e89_row0_col1 {
#   background-color: #67001f;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_83e89_row1_col1 {
#   background-color: #dd2075;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_83e89_row2_col1 {
#   background-color: #c995c7;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_83e89_row3_col1 {
#   background-color: #dac6e1;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_83e89_row4_col1 {
#   background-color: #f1edf6;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_83e89_row5_col1 {
#   background-color: #f7f4f9;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_83e89_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_83e89_row0_col0" class="data row0 col0" >K-Nearest Neighbour</td>
#       <td id="T_83e89_row0_col1" class="data row0 col1" >94.750656</td>
#     </tr>
#     <tr>
#       <td id="T_83e89_row1_col0" class="data row1 col0" >Random Forest</td>
#       <td id="T_83e89_row1_col1" class="data row1 col1" >91.076115</td>
#     </tr>
#     <tr>
#       <td id="T_83e89_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_83e89_row2_col1" class="data row2 col1" >87.664042</td>
#     </tr>
#     <tr>
#       <td id="T_83e89_row3_col0" class="data row3 col0" >Support Vector Machine</td>
#       <td id="T_83e89_row3_col1" class="data row3 col1" >85.826772</td>
#     </tr>
#     <tr>
#       <td id="T_83e89_row4_col0" class="data row4 col0" >Decision Tree</td>
#       <td id="T_83e89_row4_col1" class="data row4 col1" >83.989501</td>
#     </tr>
#     <tr>
#       <td id="T_83e89_row5_col0" class="data row5 col0" >Gaussian Naive Bayes</td>
#       <td id="T_83e89_row5_col1" class="data row5 col1" >83.464567</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Save the model as serialized object pickle
with open('model.pkl', 'wb') as file:
    pickle.dump(KNNClassifier, file)

# %%
import numpy as np
import pickle
from flask import Flask, request, render_template

# Load ML model
model = pickle.load(open('model.pkl', 'rb')) 

# Create application
app = Flask(__name__)

# Bind home function to URL
@app.route('/')
def home():
    return render_template('Heart Disease Classifier.html')

# Bind predict function to URL
@app.route('/predict', methods =['POST'])
def predict():
    
    # Put all form entries values in a list 
    features = [float(i) for i in request.form.values()]
    # Convert features to array
    array_features = [np.array(features)]
    # Predict features
    prediction = model.predict(array_features)
    
    output = prediction
    
    # Check the output values and retrive the result with html tag based on the value
    if output == 1:
        return render_template('Heart Disease Classifier.html', 
                               result = 'The patient is not likely to have heart disease!')
    else:
        return render_template('Heart Disease Classifier.html', 
                               result = 'The patient is likely to have heart disease!')

if __name__ == '__main__':
#Run the application
    app.run()
